# %%
import requests

# %%
import requests

url = "https://jupiterapi.1mg.com/api/v4/search/autocomplete"

payload={'q': 'dolo', 'types': 'allopathy'}

headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, params=payload)

print(response.text)
# Out:
# {"is_success": false, "status_code": 400, "error": {"message": "Invalid request", "errors": [{"message": "Invalid request"}]}}
